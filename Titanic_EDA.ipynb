# %% [markdown]
# # Titanic Data Cleaning & Exploratory Data Analysis
# This notebook performs data cleaning and EDA on the Titanic dataset.

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Load the Dataset

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ### 3. Basic Information about the Data

# %%
# print(df.info())
# print(df.describe())
print("Total null values: \n", df.isnull().sum())
# Out:
# Total null values:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #NULL VALUES
#
# cabin
# embarked
# age

# %% [markdown]
# ### 4. Data Cleaning
# - Fill missing `Embarked` with mode
# - Fill missing `Age` with median
# - Drop `Cabin` due to many missing values

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df['Age'].fillna(df['Age'].median(), inplace=True)
df.drop('Cabin', axis=1, inplace=True)
# Out:
# C:\Users\Brahmi\AppData\Local\Temp\ipykernel_11692\1590235609.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# C:\Users\Brahmi\AppData\Local\Temp\ipykernel_11692\1590235609.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### 5. Set Seaborn Style

# %%
sns.set(style='whitegrid')

# %% [markdown]
# ### 6. Survival Count by Sex

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Survival Count by Sex')
plt.show()

# %% [markdown]
# ### 7. Survival Count by Passenger Class

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Survival Count by Class')
plt.show()

# %% [markdown]
# ### 8. Age Distribution

# %%
sns.histplot(df['Age'], kde=True, bins=30)
plt.title('Age Distribution of Passengers')
plt.show()

# %% [markdown]
# ### 9. Boxplot of Age by Survival

# %%
sns.boxplot(x='Survived', y='Age', data=df)
plt.title('Age Distribution by Survival')
plt.show()

# %% [markdown]
# ### 10. Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### 11. Violin Plot of Fare by Class and Survival

# %%
sns.violinplot(x='Pclass', y='Fare', hue='Survived', data=df, split=True)
plt.title('Fare Distribution by Class and Survival')
plt.show()
